# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ast
import datetime

# %%
df = pd.read_csv('final_data_downloaded.csv')
df
# Out:
#         Unnamed: 0             Port_IDs  activeBuy positionSide  side  \
# 0                0  3925368433214965504       True         LONG   BUY
# 1                1  3925368433214965504      False         LONG   BUY
# 2                2  3925368433214965504      False         LONG   BUY
# 3                3  3925368433214965504       True         LONG   BUY
# 4                4  3925368433214965504       True         LONG   BUY
# ...            ...                  ...        ...          ...   ...
# 211272      211272  3768170840939476993      False         BOTH  SELL
# 211273      211273  3768170840939476993      False         BOTH  SELL
# 211274      211274  3768170840939476993      False         BOTH  SELL
# 211275      211275  3768170840939476993      False         BOTH  SELL
# 211276      211276  3768170840939476993      False         BOTH  SELL
#
#        quantityAsset     symbol realizedProfitAsset      qty feeAsset  \
# ...

# %%
df.head()
# Out:
#    Unnamed: 0             Port_IDs  activeBuy positionSide side quantityAsset  \
# 0           0  3925368433214965504       True         LONG  BUY          USDT
# 1           1  3925368433214965504      False         LONG  BUY          USDT
# 2           2  3925368433214965504      False         LONG  BUY          USDT
# 3           3  3925368433214965504       True         LONG  BUY          USDT
# 4           4  3925368433214965504       True         LONG  BUY          USDT
#
#      symbol realizedProfitAsset      qty feeAsset baseAsset  realizedProfit  \
# 0   SOLUSDT                USDT     15.0     USDT       SOL             0.0
# 1  DOGEUSDT                USDT  11484.0     USDT      DOGE             0.0
# 2  DOGEUSDT                USDT   1621.0     USDT      DOGE             0.0
# 3  DOGEUSDT                USDT    136.0     USDT      DOGE             0.0
# 4  DOGEUSDT                USDT    757.0     USDT      DOGE             0.0
#
# ...

# %%
final_stats = df.describe(include='all')
final_stats
# Out:
#            Unnamed: 0      Port_IDs activeBuy positionSide    side  \
# count   211277.000000  2.112770e+05    211277       211277  211277
# unique            NaN           NaN         2            3       2
# top               NaN           NaN      True         BOTH     BUY
# freq              NaN           NaN    106080        78585  107292
# mean    105638.000000  3.964346e+18       NaN          NaN     NaN
# std      60990.560749  6.102597e+16       NaN          NaN     NaN
# min          0.000000  3.672755e+18       NaN          NaN     NaN
# 25%      52819.000000  3.942631e+18       NaN          NaN     NaN
# 50%     105638.000000  3.977117e+18       NaN          NaN     NaN
# 75%     158457.000000  4.011627e+18       NaN          NaN     NaN
# max     211276.000000  4.041860e+18       NaN          NaN     NaN
#
#        quantityAsset        symbol realizedProfitAsset           qty feeAsset  \
# count         211277        211277              211277  2.112770e+05   211277
# ...

# %%
column_stats = df['realizedProfit'].describe()

# Display the statistics
print(column_stats)
# Out:
# count    211277.000000
# mean          3.270818
# std          57.895095
# min       -3269.194444
# 25%           0.000000
# 50%           0.000000
# 75%           0.577590
# max        8186.254058
# Name: realizedProfit, dtype: float64

# %%
column_stats = df['quantity'].describe()

# Display the statistics
print(column_stats)
# Out:
# count    211277.000000
# mean        975.509483
# std        4667.098916
# min           0.006694
# 25%          23.340915
# 50%         127.775000
# 75%         404.012000
# max      602293.260000
# Name: quantity, dtype: float64

# %%
column_stats = df['fee'].describe()

# Display the statistics
print(column_stats)
# Out:
# count    211277.000000
# mean         -0.382787
# std           1.793858
# min        -120.458652
# 25%          -0.179868
# 50%          -0.051732
# 75%          -0.009454
# max           0.000000
# Name: fee, dtype: float64

# %%
column_stats = df['price'].describe()

# Display the statistics
print(column_stats)
# Out:
# count    211277.000000
# mean       4129.040315
# std       15363.534288
# min           0.000158
# 25%           0.143830
# 50%           2.483300
# 75%          44.621000
# max       72105.000000
# Name: price, dtype: float64

# %%
column_stats = df['price_quantity'].describe()

# Display the statistics
print(column_stats)
# Out:
# count    211277.000000
# mean        975.509483
# std        4667.098916
# min           0.006694
# 25%          23.340915
# 50%         127.775000
# 75%         404.012000
# max      602293.260000
# Name: price_quantity, dtype: float64
